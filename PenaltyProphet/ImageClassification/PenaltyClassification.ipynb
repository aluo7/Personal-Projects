# %% [markdown]
# # Setting up Dependencies

# %%
import tensorflow as tf
import numpy as np
import os
import random
import cv2
import math
import pandas as pd
import keras
from keras.preprocessing import image
from keras.utils import img_to_array
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.utils.np_utils import to_categorical
from keras.models import Model,Sequential, load_model
from keras.layers import Input,Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization, AveragePooling2D, GlobalAveragePooling2D
from keras.optimizers import Adam
from keras.utils import to_categorical
np.seterr(divide='ignore', invalid='ignore')
import PIL
WIDTH = 640
HEIGHT = 360
BATCH_SIZE = 16
train_path = "C:\\Users\\luoal\\Documents\\PenaltyProphet\\Data\\kicker_pens_simple\\train"
val_path = "C:\\Users\\luoal\\Documents\\PenaltyProphet\\Data\\kicker_pens_simple\\val"

# %%
# Connect GPU to Tensorflow
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)

# %% [markdown]
# # Create tensorflow datapipeline (Training and Validation)

# %%
train_generator = ImageDataGenerator(rescale=1./255).flow_from_directory(
    train_path,
    target_size=(HEIGHT, WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True,
    subset='training') # set as training data
valid_gen = ImageDataGenerator(rescale=1./255).flow_from_directory(
    val_path,    
    target_size=(HEIGHT, WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True,) # set as validation data
# Out:
# Found 4500 images belonging to 3 classes.
# Found 323 images belonging to 3 classes.

# %% [markdown]
# # Grab transfer DenseNet121 weights from imagenet
# - Include two additional dense layers with dropouts and batchnormalization to combat overfitting (Due to small dataset)

# %%
from keras.applications.densenet import DenseNet121
from keras.layers import Dropout
from keras.models import Model
channel = 3
num_classes = 3
nb_epoch = 10

base_model = DenseNet121(include_top=False, weights='imagenet', input_shape=(HEIGHT,WIDTH,channel)) #keras.applications.vgg16.VGG16(include_top=False, weights='imagenet', input_shape=(HEIGHT,WIDTH,channel))
x = base_model.output
x = Flatten()(x)
x = Dense(units=4096,activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(rate=.5)(x)
x = Dense(units=4096,activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(rate=.5)(x)
x = Dense(units=num_classes,activation='softmax')(x)

# Only make the last 2 layers trainable
for layer in base_model.layers:
    layer.trainable = False

for layer in base_model.layers[-2:]: 
    layer.trainable = True

model = Model(base_model.input, x)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 360, 640, 3  0           []
#                                 )]
#
#  zero_padding2d (ZeroPadding2D)  (None, 366, 646, 3)  0          ['input_1[0][0]']
#
#  conv1/conv (Conv2D)            (None, 180, 320, 64  9408        ['zero_padding2d[0][0]']
#                                 )
#
#  conv1/bn (BatchNormalization)  (None, 180, 320, 64  256         ['conv1/conv[0][0]']
#                                 )
#
#  conv1/relu (Activation)        (None, 180, 320, 64  0           ['conv1/bn[0][0]']
#                                 )
#
#  zero_padding2d_1 (ZeroPadding2  (None, 182, 322, 64  0          ['conv1/relu[0][0]']
#  D)                             )
#
#  pool1 (MaxPooling2D)           (None, 90, 160, 64)  0           ['zero_padding2d_1[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 90, 160, 64)  256        ['pool1[0][0]']
#  ization)
#
#  conv2_block1_0_relu (Activatio  (None, 90, 160, 64)  0          ['conv2_block1_0_bn[0][0]']
#  n)
#
#  conv2_block1_1_conv (Conv2D)   (None, 90, 160, 128  8192        ['conv2_block1_0_relu[0][0]']
#                                 )
#
#  conv2_block1_1_bn (BatchNormal  (None, 90, 160, 128  512        ['conv2_block1_1_conv[0][0]']
#  ization)                       )
#
#  conv2_block1_1_relu (Activatio  (None, 90, 160, 128  0          ['conv2_block1_1_bn[0][0]']
#  n)                             )
#
#  conv2_block1_2_conv (Conv2D)   (None, 90, 160, 32)  36864       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_concat (Concatena  (None, 90, 160, 96)  0          ['pool1[0][0]',
#  te)                                                              'conv2_block1_2_conv[0][0]']
#
#  conv2_block2_0_bn (BatchNormal  (None, 90, 160, 96)  384        ['conv2_block1_concat[0][0]']
#  ization)
#
#  conv2_block2_0_relu (Activatio  (None, 90, 160, 96)  0          ['conv2_block2_0_bn[0][0]']
#  n)
#
#  conv2_block2_1_conv (Conv2D)   (None, 90, 160, 128  12288       ['conv2_block2_0_relu[0][0]']
#                                 )
#
#  conv2_block2_1_bn (BatchNormal  (None, 90, 160, 128  512        ['conv2_block2_1_conv[0][0]']
#  ization)                       )
#
#  conv2_block2_1_relu (Activatio  (None, 90, 160, 128  0          ['conv2_block2_1_bn[0][0]']
#  n)                             )
#
#  conv2_block2_2_conv (Conv2D)   (None, 90, 160, 32)  36864       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_concat (Concatena  (None, 90, 160, 128  0          ['conv2_block1_concat[0][0]',
#  te)                            )                                 'conv2_block2_2_conv[0][0]']
#
#  conv2_block3_0_bn (BatchNormal  (None, 90, 160, 128  512        ['conv2_block2_concat[0][0]']
#  ization)                       )
#
#  conv2_block3_0_relu (Activatio  (None, 90, 160, 128  0          ['conv2_block3_0_bn[0][0]']
#  n)                             )
#
#  conv2_block3_1_conv (Conv2D)   (None, 90, 160, 128  16384       ['conv2_block3_0_relu[0][0]']
#                                 )
#
#  conv2_block3_1_bn (BatchNormal  (None, 90, 160, 128  512        ['conv2_block3_1_conv[0][0]']
#  ization)                       )
#
#  conv2_block3_1_relu (Activatio  (None, 90, 160, 128  0          ['conv2_block3_1_bn[0][0]']
#  n)                             )
#
#  conv2_block3_2_conv (Conv2D)   (None, 90, 160, 32)  36864       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_concat (Concatena  (None, 90, 160, 160  0          ['conv2_block2_concat[0][0]',
#  te)                            )                                 'conv2_block3_2_conv[0][0]']
#
#  conv2_block4_0_bn (BatchNormal  (None, 90, 160, 160  640        ['conv2_block3_concat[0][0]']
#  ization)                       )
#
#  conv2_block4_0_relu (Activatio  (None, 90, 160, 160  0          ['conv2_block4_0_bn[0][0]']
#  n)                             )
#
#  conv2_block4_1_conv (Conv2D)   (None, 90, 160, 128  20480       ['conv2_block4_0_relu[0][0]']
#                                 )
#
#  conv2_block4_1_bn (BatchNormal  (None, 90, 160, 128  512        ['conv2_block4_1_conv[0][0]']
#  ization)                       )
#
#  conv2_block4_1_relu (Activatio  (None, 90, 160, 128  0          ['conv2_block4_1_bn[0][0]']
#  n)                             )
#
#  conv2_block4_2_conv (Conv2D)   (None, 90, 160, 32)  36864       ['conv2_block4_1_relu[0][0]']
#
#  conv2_block4_concat (Concatena  (None, 90, 160, 192  0          ['conv2_block3_concat[0][0]',
#  te)                            )                                 'conv2_block4_2_conv[0][0]']
#
#  conv2_block5_0_bn (BatchNormal  (None, 90, 160, 192  768        ['conv2_block4_concat[0][0]']
#  ization)                       )
#
#  conv2_block5_0_relu (Activatio  (None, 90, 160, 192  0          ['conv2_block5_0_bn[0][0]']
#  n)                             )
#
#  conv2_block5_1_conv (Conv2D)   (None, 90, 160, 128  24576       ['conv2_block5_0_relu[0][0]']
#                                 )
#
#  conv2_block5_1_bn (BatchNormal  (None, 90, 160, 128  512        ['conv2_block5_1_conv[0][0]']
#  ization)                       )
#
#  conv2_block5_1_relu (Activatio  (None, 90, 160, 128  0          ['conv2_block5_1_bn[0][0]']
#  n)                             )
#
#  conv2_block5_2_conv (Conv2D)   (None, 90, 160, 32)  36864       ['conv2_block5_1_relu[0][0]']
#
#  conv2_block5_concat (Concatena  (None, 90, 160, 224  0          ['conv2_block4_concat[0][0]',
#  te)                            )                                 'conv2_block5_2_conv[0][0]']
#
#  conv2_block6_0_bn (BatchNormal  (None, 90, 160, 224  896        ['conv2_block5_concat[0][0]']
#  ization)                       )
#
#  conv2_block6_0_relu (Activatio  (None, 90, 160, 224  0          ['conv2_block6_0_bn[0][0]']
#  n)                             )
#
#  conv2_block6_1_conv (Conv2D)   (None, 90, 160, 128  28672       ['conv2_block6_0_relu[0][0]']
#                                 )
#
#  conv2_block6_1_bn (BatchNormal  (None, 90, 160, 128  512        ['conv2_block6_1_conv[0][0]']
#  ization)                       )
#
#  conv2_block6_1_relu (Activatio  (None, 90, 160, 128  0          ['conv2_block6_1_bn[0][0]']
#  n)                             )
#
#  conv2_block6_2_conv (Conv2D)   (None, 90, 160, 32)  36864       ['conv2_block6_1_relu[0][0]']
#
#  conv2_block6_concat (Concatena  (None, 90, 160, 256  0          ['conv2_block5_concat[0][0]',
#  te)                            )                                 'conv2_block6_2_conv[0][0]']
#
#  pool2_bn (BatchNormalization)  (None, 90, 160, 256  1024        ['conv2_block6_concat[0][0]']
#                                 )
#
#  pool2_relu (Activation)        (None, 90, 160, 256  0           ['pool2_bn[0][0]']
#                                 )
#
#  pool2_conv (Conv2D)            (None, 90, 160, 128  32768       ['pool2_relu[0][0]']
#                                 )
#
#  pool2_pool (AveragePooling2D)  (None, 45, 80, 128)  0           ['pool2_conv[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 45, 80, 128)  512        ['pool2_pool[0][0]']
#  ization)
#
#  conv3_block1_0_relu (Activatio  (None, 45, 80, 128)  0          ['conv3_block1_0_bn[0][0]']
#  n)
#
#  conv3_block1_1_conv (Conv2D)   (None, 45, 80, 128)  16384       ['conv3_block1_0_relu[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 45, 80, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 45, 80, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 45, 80, 32)   36864       ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_concat (Concatena  (None, 45, 80, 160)  0          ['pool2_pool[0][0]',
#  te)                                                              'conv3_block1_2_conv[0][0]']
#
#  conv3_block2_0_bn (BatchNormal  (None, 45, 80, 160)  640        ['conv3_block1_concat[0][0]']
#  ization)
#
#  conv3_block2_0_relu (Activatio  (None, 45, 80, 160)  0          ['conv3_block2_0_bn[0][0]']
#  n)
#
#  conv3_block2_1_conv (Conv2D)   (None, 45, 80, 128)  20480       ['conv3_block2_0_relu[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 45, 80, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 45, 80, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 45, 80, 32)   36864       ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_concat (Concatena  (None, 45, 80, 192)  0          ['conv3_block1_concat[0][0]',
#  te)                                                              'conv3_block2_2_conv[0][0]']
#
#  conv3_block3_0_bn (BatchNormal  (None, 45, 80, 192)  768        ['conv3_block2_concat[0][0]']
#  ization)
#
#  conv3_block3_0_relu (Activatio  (None, 45, 80, 192)  0          ['conv3_block3_0_bn[0][0]']
#  n)
#
#  conv3_block3_1_conv (Conv2D)   (None, 45, 80, 128)  24576       ['conv3_block3_0_relu[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 45, 80, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 45, 80, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 45, 80, 32)   36864       ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_concat (Concatena  (None, 45, 80, 224)  0          ['conv3_block2_concat[0][0]',
#  te)                                                              'conv3_block3_2_conv[0][0]']
#
#  conv3_block4_0_bn (BatchNormal  (None, 45, 80, 224)  896        ['conv3_block3_concat[0][0]']
#  ization)
#
#  conv3_block4_0_relu (Activatio  (None, 45, 80, 224)  0          ['conv3_block4_0_bn[0][0]']
#  n)
#
#  conv3_block4_1_conv (Conv2D)   (None, 45, 80, 128)  28672       ['conv3_block4_0_relu[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 45, 80, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 45, 80, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 45, 80, 32)   36864       ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_concat (Concatena  (None, 45, 80, 256)  0          ['conv3_block3_concat[0][0]',
#  te)                                                              'conv3_block4_2_conv[0][0]']
#
#  conv3_block5_0_bn (BatchNormal  (None, 45, 80, 256)  1024       ['conv3_block4_concat[0][0]']
#  ization)
#
#  conv3_block5_0_relu (Activatio  (None, 45, 80, 256)  0          ['conv3_block5_0_bn[0][0]']
#  n)
#
#  conv3_block5_1_conv (Conv2D)   (None, 45, 80, 128)  32768       ['conv3_block5_0_relu[0][0]']
#
#  conv3_block5_1_bn (BatchNormal  (None, 45, 80, 128)  512        ['conv3_block5_1_conv[0][0]']
#  ization)
#
#  conv3_block5_1_relu (Activatio  (None, 45, 80, 128)  0          ['conv3_block5_1_bn[0][0]']
#  n)
#
#  conv3_block5_2_conv (Conv2D)   (None, 45, 80, 32)   36864       ['conv3_block5_1_relu[0][0]']
#
#  conv3_block5_concat (Concatena  (None, 45, 80, 288)  0          ['conv3_block4_concat[0][0]',
#  te)                                                              'conv3_block5_2_conv[0][0]']
#
#  conv3_block6_0_bn (BatchNormal  (None, 45, 80, 288)  1152       ['conv3_block5_concat[0][0]']
#  ization)
#
#  conv3_block6_0_relu (Activatio  (None, 45, 80, 288)  0          ['conv3_block6_0_bn[0][0]']
#  n)
#
#  conv3_block6_1_conv (Conv2D)   (None, 45, 80, 128)  36864       ['conv3_block6_0_relu[0][0]']
#
#  conv3_block6_1_bn (BatchNormal  (None, 45, 80, 128)  512        ['conv3_block6_1_conv[0][0]']
#  ization)
#
#  conv3_block6_1_relu (Activatio  (None, 45, 80, 128)  0          ['conv3_block6_1_bn[0][0]']
#  n)
#
#  conv3_block6_2_conv (Conv2D)   (None, 45, 80, 32)   36864       ['conv3_block6_1_relu[0][0]']
#
#  conv3_block6_concat (Concatena  (None, 45, 80, 320)  0          ['conv3_block5_concat[0][0]',
#  te)                                                              'conv3_block6_2_conv[0][0]']
#
#  conv3_block7_0_bn (BatchNormal  (None, 45, 80, 320)  1280       ['conv3_block6_concat[0][0]']
#  ization)
#
#  conv3_block7_0_relu (Activatio  (None, 45, 80, 320)  0          ['conv3_block7_0_bn[0][0]']
#  n)
#
#  conv3_block7_1_conv (Conv2D)   (None, 45, 80, 128)  40960       ['conv3_block7_0_relu[0][0]']
#
#  conv3_block7_1_bn (BatchNormal  (None, 45, 80, 128)  512        ['conv3_block7_1_conv[0][0]']
#  ization)
#
#  conv3_block7_1_relu (Activatio  (None, 45, 80, 128)  0          ['conv3_block7_1_bn[0][0]']
#  n)
#
#  conv3_block7_2_conv (Conv2D)   (None, 45, 80, 32)   36864       ['conv3_block7_1_relu[0][0]']
#
#  conv3_block7_concat (Concatena  (None, 45, 80, 352)  0          ['conv3_block6_concat[0][0]',
#  te)                                                              'conv3_block7_2_conv[0][0]']
#
#  conv3_block8_0_bn (BatchNormal  (None, 45, 80, 352)  1408       ['conv3_block7_concat[0][0]']
#  ization)
#
#  conv3_block8_0_relu (Activatio  (None, 45, 80, 352)  0          ['conv3_block8_0_bn[0][0]']
#  n)
#
#  conv3_block8_1_conv (Conv2D)   (None, 45, 80, 128)  45056       ['conv3_block8_0_relu[0][0]']
#
#  conv3_block8_1_bn (BatchNormal  (None, 45, 80, 128)  512        ['conv3_block8_1_conv[0][0]']
#  ization)
#
#  conv3_block8_1_relu (Activatio  (None, 45, 80, 128)  0          ['conv3_block8_1_bn[0][0]']
#  n)
#
#  conv3_block8_2_conv (Conv2D)   (None, 45, 80, 32)   36864       ['conv3_block8_1_relu[0][0]']
#
#  conv3_block8_concat (Concatena  (None, 45, 80, 384)  0          ['conv3_block7_concat[0][0]',
#  te)                                                              'conv3_block8_2_conv[0][0]']
#
#  conv3_block9_0_bn (BatchNormal  (None, 45, 80, 384)  1536       ['conv3_block8_concat[0][0]']
#  ization)
#
#  conv3_block9_0_relu (Activatio  (None, 45, 80, 384)  0          ['conv3_block9_0_bn[0][0]']
#  n)
#
#  conv3_block9_1_conv (Conv2D)   (None, 45, 80, 128)  49152       ['conv3_block9_0_relu[0][0]']
#
#  conv3_block9_1_bn (BatchNormal  (None, 45, 80, 128)  512        ['conv3_block9_1_conv[0][0]']
#  ization)
#
#  conv3_block9_1_relu (Activatio  (None, 45, 80, 128)  0          ['conv3_block9_1_bn[0][0]']
#  n)
#
#  conv3_block9_2_conv (Conv2D)   (None, 45, 80, 32)   36864       ['conv3_block9_1_relu[0][0]']
#
#  conv3_block9_concat (Concatena  (None, 45, 80, 416)  0          ['conv3_block8_concat[0][0]',
#  te)                                                              'conv3_block9_2_conv[0][0]']
#
#  conv3_block10_0_bn (BatchNorma  (None, 45, 80, 416)  1664       ['conv3_block9_concat[0][0]']
#  lization)
#
#  conv3_block10_0_relu (Activati  (None, 45, 80, 416)  0          ['conv3_block10_0_bn[0][0]']
#  on)
#
#  conv3_block10_1_conv (Conv2D)  (None, 45, 80, 128)  53248       ['conv3_block10_0_relu[0][0]']
#
#  conv3_block10_1_bn (BatchNorma  (None, 45, 80, 128)  512        ['conv3_block10_1_conv[0][0]']
#  lization)
#
#  conv3_block10_1_relu (Activati  (None, 45, 80, 128)  0          ['conv3_block10_1_bn[0][0]']
#  on)
#
#  conv3_block10_2_conv (Conv2D)  (None, 45, 80, 32)   36864       ['conv3_block10_1_relu[0][0]']
#
#  conv3_block10_concat (Concaten  (None, 45, 80, 448)  0          ['conv3_block9_concat[0][0]',
#  ate)                                                             'conv3_block10_2_conv[0][0]']
#
#  conv3_block11_0_bn (BatchNorma  (None, 45, 80, 448)  1792       ['conv3_block10_concat[0][0]']
#  lization)
#
#  conv3_block11_0_relu (Activati  (None, 45, 80, 448)  0          ['conv3_block11_0_bn[0][0]']
#  on)
#
#  conv3_block11_1_conv (Conv2D)  (None, 45, 80, 128)  57344       ['conv3_block11_0_relu[0][0]']
#
#  conv3_block11_1_bn (BatchNorma  (None, 45, 80, 128)  512        ['conv3_block11_1_conv[0][0]']
#  lization)
#
#  conv3_block11_1_relu (Activati  (None, 45, 80, 128)  0          ['conv3_block11_1_bn[0][0]']
#  on)
#
#  conv3_block11_2_conv (Conv2D)  (None, 45, 80, 32)   36864       ['conv3_block11_1_relu[0][0]']
#
#  conv3_block11_concat (Concaten  (None, 45, 80, 480)  0          ['conv3_block10_concat[0][0]',
#  ate)                                                             'conv3_block11_2_conv[0][0]']
#
#  conv3_block12_0_bn (BatchNorma  (None, 45, 80, 480)  1920       ['conv3_block11_concat[0][0]']
#  lization)
#
#  conv3_block12_0_relu (Activati  (None, 45, 80, 480)  0          ['conv3_block12_0_bn[0][0]']
#  on)
#
#  conv3_block12_1_conv (Conv2D)  (None, 45, 80, 128)  61440       ['conv3_block12_0_relu[0][0]']
#
#  conv3_block12_1_bn (BatchNorma  (None, 45, 80, 128)  512        ['conv3_block12_1_conv[0][0]']
#  lization)
#
#  conv3_block12_1_relu (Activati  (None, 45, 80, 128)  0          ['conv3_block12_1_bn[0][0]']
#  on)
#
#  conv3_block12_2_conv (Conv2D)  (None, 45, 80, 32)   36864       ['conv3_block12_1_relu[0][0]']
#
#  conv3_block12_concat (Concaten  (None, 45, 80, 512)  0          ['conv3_block11_concat[0][0]',
#  ate)                                                             'conv3_block12_2_conv[0][0]']
#
#  pool3_bn (BatchNormalization)  (None, 45, 80, 512)  2048        ['conv3_block12_concat[0][0]']
#
#  pool3_relu (Activation)        (None, 45, 80, 512)  0           ['pool3_bn[0][0]']
#
#  pool3_conv (Conv2D)            (None, 45, 80, 256)  131072      ['pool3_relu[0][0]']
#
#  pool3_pool (AveragePooling2D)  (None, 22, 40, 256)  0           ['pool3_conv[0][0]']
#
#  conv4_block1_0_bn (BatchNormal  (None, 22, 40, 256)  1024       ['pool3_pool[0][0]']
#  ization)
#
#  conv4_block1_0_relu (Activatio  (None, 22, 40, 256)  0          ['conv4_block1_0_bn[0][0]']
#  n)
#
#  conv4_block1_1_conv (Conv2D)   (None, 22, 40, 128)  32768       ['conv4_block1_0_relu[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 22, 40, 128)  512        ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 22, 40, 128)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 22, 40, 32)   36864       ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_concat (Concatena  (None, 22, 40, 288)  0          ['pool3_pool[0][0]',
#  te)                                                              'conv4_block1_2_conv[0][0]']
#
#  conv4_block2_0_bn (BatchNormal  (None, 22, 40, 288)  1152       ['conv4_block1_concat[0][0]']
#  ization)
#
#  conv4_block2_0_relu (Activatio  (None, 22, 40, 288)  0          ['conv4_block2_0_bn[0][0]']
#  n)
#
#  conv4_block2_1_conv (Conv2D)   (None, 22, 40, 128)  36864       ['conv4_block2_0_relu[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 22, 40, 128)  512        ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 22, 40, 128)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 22, 40, 32)   36864       ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_concat (Concatena  (None, 22, 40, 320)  0          ['conv4_block1_concat[0][0]',
#  te)                                                              'conv4_block2_2_conv[0][0]']
#
#  conv4_block3_0_bn (BatchNormal  (None, 22, 40, 320)  1280       ['conv4_block2_concat[0][0]']
#  ization)
#
#  conv4_block3_0_relu (Activatio  (None, 22, 40, 320)  0          ['conv4_block3_0_bn[0][0]']
#  n)
#
#  conv4_block3_1_conv (Conv2D)   (None, 22, 40, 128)  40960       ['conv4_block3_0_relu[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 22, 40, 128)  512        ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 22, 40, 128)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 22, 40, 32)   36864       ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_concat (Concatena  (None, 22, 40, 352)  0          ['conv4_block2_concat[0][0]',
#  te)                                                              'conv4_block3_2_conv[0][0]']
#
#  conv4_block4_0_bn (BatchNormal  (None, 22, 40, 352)  1408       ['conv4_block3_concat[0][0]']
#  ization)
#
#  conv4_block4_0_relu (Activatio  (None, 22, 40, 352)  0          ['conv4_block4_0_bn[0][0]']
#  n)
#
#  conv4_block4_1_conv (Conv2D)   (None, 22, 40, 128)  45056       ['conv4_block4_0_relu[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 22, 40, 128)  512        ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 22, 40, 128)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 22, 40, 32)   36864       ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_concat (Concatena  (None, 22, 40, 384)  0          ['conv4_block3_concat[0][0]',
#  te)                                                              'conv4_block4_2_conv[0][0]']
#
#  conv4_block5_0_bn (BatchNormal  (None, 22, 40, 384)  1536       ['conv4_block4_concat[0][0]']
#  ization)
#
#  conv4_block5_0_relu (Activatio  (None, 22, 40, 384)  0          ['conv4_block5_0_bn[0][0]']
#  n)
#
#  conv4_block5_1_conv (Conv2D)   (None, 22, 40, 128)  49152       ['conv4_block5_0_relu[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 22, 40, 128)  512        ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 22, 40, 128)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 22, 40, 32)   36864       ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_concat (Concatena  (None, 22, 40, 416)  0          ['conv4_block4_concat[0][0]',
#  te)                                                              'conv4_block5_2_conv[0][0]']
#
# ...
#
#  conv5_block10_0_bn (BatchNorma  (None, 11, 20, 800)  3200       ['conv5_block9_concat[0][0]']
#  lization)
#
#  conv5_block10_0_relu (Activati  (None, 11, 20, 800)  0          ['conv5_block10_0_bn[0][0]']
#  on)
#
#  conv5_block10_1_conv (Conv2D)  (None, 11, 20, 128)  102400      ['conv5_block10_0_relu[0][0]']
#
#  conv5_block10_1_bn (BatchNorma  (None, 11, 20, 128)  512        ['conv5_block10_1_conv[0][0]']
#  lization)
#
#  conv5_block10_1_relu (Activati  (None, 11, 20, 128)  0          ['conv5_block10_1_bn[0][0]']
#  on)
#
#  conv5_block10_2_conv (Conv2D)  (None, 11, 20, 32)   36864       ['conv5_block10_1_relu[0][0]']
#
#  conv5_block10_concat (Concaten  (None, 11, 20, 832)  0          ['conv5_block9_concat[0][0]',
#  ate)                                                             'conv5_block10_2_conv[0][0]']
#
#  conv5_block11_0_bn (BatchNorma  (None, 11, 20, 832)  3328       ['conv5_block10_concat[0][0]']
#  lization)
#
#  conv5_block11_0_relu (Activati  (None, 11, 20, 832)  0          ['conv5_block11_0_bn[0][0]']
#  on)
#
#  conv5_block11_1_conv (Conv2D)  (None, 11, 20, 128)  106496      ['conv5_block11_0_relu[0][0]']
#
#  conv5_block11_1_bn (BatchNorma  (None, 11, 20, 128)  512        ['conv5_block11_1_conv[0][0]']
#  lization)
#
#  conv5_block11_1_relu (Activati  (None, 11, 20, 128)  0          ['conv5_block11_1_bn[0][0]']
#  on)
#
#  conv5_block11_2_conv (Conv2D)  (None, 11, 20, 32)   36864       ['conv5_block11_1_relu[0][0]']
#
#  conv5_block11_concat (Concaten  (None, 11, 20, 864)  0          ['conv5_block10_concat[0][0]',
#  ate)                                                             'conv5_block11_2_conv[0][0]']
#
#  conv5_block12_0_bn (BatchNorma  (None, 11, 20, 864)  3456       ['conv5_block11_concat[0][0]']
#  lization)
#
#  conv5_block12_0_relu (Activati  (None, 11, 20, 864)  0          ['conv5_block12_0_bn[0][0]']
#  on)
#
#  conv5_block12_1_conv (Conv2D)  (None, 11, 20, 128)  110592      ['conv5_block12_0_relu[0][0]']
#
#  conv5_block12_1_bn (BatchNorma  (None, 11, 20, 128)  512        ['conv5_block12_1_conv[0][0]']
#  lization)
#
#  conv5_block12_1_relu (Activati  (None, 11, 20, 128)  0          ['conv5_block12_1_bn[0][0]']
#  on)
#
#  conv5_block12_2_conv (Conv2D)  (None, 11, 20, 32)   36864       ['conv5_block12_1_relu[0][0]']
#
#  conv5_block12_concat (Concaten  (None, 11, 20, 896)  0          ['conv5_block11_concat[0][0]',
#  ate)                                                             'conv5_block12_2_conv[0][0]']
#
#  conv5_block13_0_bn (BatchNorma  (None, 11, 20, 896)  3584       ['conv5_block12_concat[0][0]']
#  lization)
#
#  conv5_block13_0_relu (Activati  (None, 11, 20, 896)  0          ['conv5_block13_0_bn[0][0]']
#  on)
#
#  conv5_block13_1_conv (Conv2D)  (None, 11, 20, 128)  114688      ['conv5_block13_0_relu[0][0]']
#
#  conv5_block13_1_bn (BatchNorma  (None, 11, 20, 128)  512        ['conv5_block13_1_conv[0][0]']
#  lization)
#
#  conv5_block13_1_relu (Activati  (None, 11, 20, 128)  0          ['conv5_block13_1_bn[0][0]']
#  on)
#
#  conv5_block13_2_conv (Conv2D)  (None, 11, 20, 32)   36864       ['conv5_block13_1_relu[0][0]']
#
#  conv5_block13_concat (Concaten  (None, 11, 20, 928)  0          ['conv5_block12_concat[0][0]',
#  ate)                                                             'conv5_block13_2_conv[0][0]']
#
#  conv5_block14_0_bn (BatchNorma  (None, 11, 20, 928)  3712       ['conv5_block13_concat[0][0]']
#  lization)
#
#  conv5_block14_0_relu (Activati  (None, 11, 20, 928)  0          ['conv5_block14_0_bn[0][0]']
#  on)
#
#  conv5_block14_1_conv (Conv2D)  (None, 11, 20, 128)  118784      ['conv5_block14_0_relu[0][0]']
#
#  conv5_block14_1_bn (BatchNorma  (None, 11, 20, 128)  512        ['conv5_block14_1_conv[0][0]']
#  lization)
#
#  conv5_block14_1_relu (Activati  (None, 11, 20, 128)  0          ['conv5_block14_1_bn[0][0]']
#  on)
#
#  conv5_block14_2_conv (Conv2D)  (None, 11, 20, 32)   36864       ['conv5_block14_1_relu[0][0]']
#
#  conv5_block14_concat (Concaten  (None, 11, 20, 960)  0          ['conv5_block13_concat[0][0]',
#  ate)                                                             'conv5_block14_2_conv[0][0]']
#
#  conv5_block15_0_bn (BatchNorma  (None, 11, 20, 960)  3840       ['conv5_block14_concat[0][0]']
#  lization)
#
#  conv5_block15_0_relu (Activati  (None, 11, 20, 960)  0          ['conv5_block15_0_bn[0][0]']
#  on)
#
#  conv5_block15_1_conv (Conv2D)  (None, 11, 20, 128)  122880      ['conv5_block15_0_relu[0][0]']
#
#  conv5_block15_1_bn (BatchNorma  (None, 11, 20, 128)  512        ['conv5_block15_1_conv[0][0]']
#  lization)
#
#  conv5_block15_1_relu (Activati  (None, 11, 20, 128)  0          ['conv5_block15_1_bn[0][0]']
#  on)
#
#  conv5_block15_2_conv (Conv2D)  (None, 11, 20, 32)   36864       ['conv5_block15_1_relu[0][0]']
#
#  conv5_block15_concat (Concaten  (None, 11, 20, 992)  0          ['conv5_block14_concat[0][0]',
#  ate)                                                             'conv5_block15_2_conv[0][0]']
#
#  conv5_block16_0_bn (BatchNorma  (None, 11, 20, 992)  3968       ['conv5_block15_concat[0][0]']
#  lization)
#
#  conv5_block16_0_relu (Activati  (None, 11, 20, 992)  0          ['conv5_block16_0_bn[0][0]']
#  on)
#
#  conv5_block16_1_conv (Conv2D)  (None, 11, 20, 128)  126976      ['conv5_block16_0_relu[0][0]']
#
#  conv5_block16_1_bn (BatchNorma  (None, 11, 20, 128)  512        ['conv5_block16_1_conv[0][0]']
#  lization)
#
#  conv5_block16_1_relu (Activati  (None, 11, 20, 128)  0          ['conv5_block16_1_bn[0][0]']
#  on)
#
#  conv5_block16_2_conv (Conv2D)  (None, 11, 20, 32)   36864       ['conv5_block16_1_relu[0][0]']
#
#  conv5_block16_concat (Concaten  (None, 11, 20, 1024  0          ['conv5_block15_concat[0][0]',
#  ate)                           )                                 'conv5_block16_2_conv[0][0]']
#
#  bn (BatchNormalization)        (None, 11, 20, 1024  4096        ['conv5_block16_concat[0][0]']
#                                 )
#
#  relu (Activation)              (None, 11, 20, 1024  0           ['bn[0][0]']
#                                 )
#
#  flatten (Flatten)              (None, 225280)       0           ['relu[0][0]']
#
#  dense (Dense)                  (None, 4096)         922750976   ['flatten[0][0]']
#
#  batch_normalization (BatchNorm  (None, 4096)        16384       ['dense[0][0]']
#  alization)
#
#  dropout (Dropout)              (None, 4096)         0           ['batch_normalization[0][0]']
#
#  dense_1 (Dense)                (None, 4096)         16781312    ['dropout[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 4096)        16384       ['dense_1[0][0]']
#  rmalization)
#
#  dropout_1 (Dropout)            (None, 4096)         0           ['batch_normalization_1[0][0]']
#
#  dense_2 (Dense)                (None, 3)            12291       ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 946,614,851
# Trainable params: 939,563,011
# Non-trainable params: 7,051,840
# __________________________________________________________________________________________________

# %% [markdown]
# # Train dataset for 10 epochs

# %%
filepath="bestmodel_kicker.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
annealer = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=3, verbose=1, min_lr=1e-5)
callbacks_list = [annealer,checkpoint]
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

history = model.fit(
            train_generator,
            steps_per_epoch = train_generator.samples // BATCH_SIZE,
            validation_data = valid_gen, 
            validation_steps = valid_gen.samples // BATCH_SIZE,
            epochs = nb_epoch,
            verbose=1,
            callbacks=callbacks_list)
# Out:
# Epoch 1/10
# 281/281 [==============================] - ETA: 0s - loss: 1.9159 - accuracy: 0.5598
# Epoch 1: val_accuracy improved from -inf to 0.73125, saving model to bestmodel_kicker.hdf5
# 281/281 [==============================] - 1347s 5s/step - loss: 1.9159 - accuracy: 0.5598 - val_loss: 1.8921 - val_accuracy: 0.7312 - lr: 0.0010
# Epoch 2/10
# 281/281 [==============================] - ETA: 0s - loss: 1.0762 - accuracy: 0.6956
# Epoch 2: val_accuracy improved from 0.73125 to 0.85312, saving model to bestmodel_kicker.hdf5
# 281/281 [==============================] - 1310s 5s/step - loss: 1.0762 - accuracy: 0.6956 - val_loss: 0.7456 - val_accuracy: 0.8531 - lr: 0.0010
# Epoch 3/10
# 281/281 [==============================] - ETA: 0s - loss: 0.6955 - accuracy: 0.7964
# Epoch 3: val_accuracy improved from 0.85312 to 0.92188, saving model to bestmodel_kicker.hdf5
# 281/281 [==============================] - 1300s 5s/step - loss: 0.6955 - accuracy: 0.7964 - val_loss: 0.2598 - val_accuracy: 0.9219 - lr: 0.0010
# Epoch 4/10
# 281/281 [==============================] - ETA: 0s - loss: 0.5368 - accuracy: 0.8437
# Epoch 4: val_accuracy did not improve from 0.92188
# 281/281 [==============================] - 1264s 4s/step - loss: 0.5368 - accuracy: 0.8437 - val_loss: 0.3154 - val_accuracy: 0.9094 - lr: 0.0010
# Epoch 5/10
# 281/281 [==============================] - ETA: 0s - loss: 0.5346 - accuracy: 0.8570
# Epoch 5: val_accuracy did not improve from 0.92188
# 281/281 [==============================] - 1262s 4s/step - loss: 0.5346 - accuracy: 0.8570 - val_loss: 0.4588 - val_accuracy: 0.9219 - lr: 0.0010
# Epoch 6/10
# 281/281 [==============================] - ETA: 0s - loss: 0.3879 - accuracy: 0.8896
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 6: val_accuracy did not improve from 0.92188
# 281/281 [==============================] - 1263s 4s/step - loss: 0.3879 - accuracy: 0.8896 - val_loss: 0.4293 - val_accuracy: 0.8781 - lr: 0.0010
# Epoch 7/10
# 281/281 [==============================] - ETA: 0s - loss: 0.1915 - accuracy: 0.9391
# Epoch 7: val_accuracy improved from 0.92188 to 0.97500, saving model to bestmodel_kicker.hdf5
# 281/281 [==============================] - 1299s 5s/step - loss: 0.1915 - accuracy: 0.9391 - val_loss: 0.0774 - val_accuracy: 0.9750 - lr: 5.0000e-04
# Epoch 8/10
# 281/281 [==============================] - ETA: 0s - loss: 0.1536 - accuracy: 0.9527
# Epoch 8: val_accuracy did not improve from 0.97500
# 281/281 [==============================] - 1273s 5s/step - loss: 0.1536 - accuracy: 0.9527 - val_loss: 0.0934 - val_accuracy: 0.9750 - lr: 5.0000e-04
# Epoch 9/10
# 281/281 [==============================] - ETA: 0s - loss: 0.1085 - accuracy: 0.9652
# Epoch 9: val_accuracy improved from 0.97500 to 0.98438, saving model to bestmodel_kicker.hdf5
# 281/281 [==============================] - 1297s 5s/step - loss: 0.1085 - accuracy: 0.9652 - val_loss: 0.0646 - val_accuracy: 0.9844 - lr: 5.0000e-04
# Epoch 10/10
# 281/281 [==============================] - ETA: 0s - loss: 0.1238 - accuracy: 0.9616
# Epoch 10: val_accuracy did not improve from 0.98438
# 281/281 [==============================] - 1261s 4s/step - loss: 0.1238 - accuracy: 0.9616 - val_loss: 0.1948 - val_accuracy: 0.9438 - lr: 5.0000e-04

# %%
from matplotlib import pyplot as plt
fig,(ax1, ax2) = plt.subplots(1, 2, figsize=(18, 8))

# accuracy
ax1.plot(history.history['accuracy'], color='red')
ax1.plot(history.history['val_accuracy'], color='green')
ax1.set_title('Model accuracy')
ax1.set_ylabel('Accuracy')
ax1.set_xlabel('Epoch')
ax1.legend(['train', 'validation'], loc='lower right')

# "Loss"
ax2.plot(history.history['loss'], color='red')
ax2.plot(history.history['val_loss'], color='green')
ax2.set_title('Model loss')
ax2.set_ylabel('Loss')
ax2.set_xlabel('Epoch')
ax2.legend(['train', 'validation'], loc='upper right')
plt.show()

# %% [markdown]
# # Test new model

# %%
test_path = "C:\\Users\\luoal\\Documents\\PenaltyProphet\\Data\\kicker_pens_simple\\test"
test = ImageDataGenerator(rescale=1./255).flow_from_directory(test_path, 
    target_size=(HEIGHT,WIDTH), batch_size=16, class_mode='categorical', shuffle=False)
# Out:
# Found 323 images belonging to 3 classes.

# %% [markdown]
# # ~98% accuracy on testing data

# %%
model = load_model('C:\\Users\\luoal\\Documents\\PenaltyProphet\\Models\\bestmodel_kicker.hdf5')
model.evaluate(test, steps=test.n//test.batch_size)
# Out:
# 20/20 [==============================] - 47s 2s/step - loss: 0.0572 - accuracy: 0.9812
# [0.05715562030673027, 0.981249988079071]

# %%
Y_Pred = model.predict(test, steps=(test.n//test.batch_size)+1)
y_pred = np.argmax(Y_Pred, axis=1)
# Out:
# 21/21 [==============================] - 49s 2s/step

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
cm = confusion_matrix(test.classes, y_pred)

#Normalize data
cmn = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
cmn = np.around(cmn, decimals=2)
fig, ax = plt.subplots(figsize=(10,5))
cmap = sns.diverging_palette(0, 100, as_cmap=True)
sns.heatmap(cmn, annot=True, fmt='.2f',cmap=cmap, xticklabels=test.class_indices.keys(), yticklabels=test.class_indices.keys())
# Out:
# <AxesSubplot:>
